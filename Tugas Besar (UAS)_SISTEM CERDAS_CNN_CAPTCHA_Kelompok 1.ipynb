# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#importing libraries
import numpy as np 
# %matplotlib inline 
import matplotlib.pyplot as plt #for graphs
import os #for operating system dependent fucntionality
import keras                                #import keras
import tensorflow as tf
from keras import layers #for building layers of neural net
from keras.models import Model
from keras.models import load_model
from keras import callbacks #for training logs, saving to disk periodically
import cv2 #OpenCV(Open Source computer vision lib), containg CV algos
import string

# %%
os.listdir("/content/drive/MyDrive/Colab Notebooks/samples")
# Out:
# ['8d8ep.png',
#  '8db67.png',
#  '8n34n.png',
#  '8n4n8.png',
#  '8n65n.png',
#  '8nbew.png',
#  '8np22.png',
#  '8wy7d.png',
#  '8ypdn.png',
#  '8xef7.png',
#  '8y63f.png',
#  '23mdg.png',
#  '25m6p.png',
#  '32cnn.png',
#  '25egp.png',
#  '36nx4.png',
#  '34b84.png',
#  '37d52.png',
#  '42xpy.png',
#  '47m2b.png',
#  '42dw4.png',
#  '56c34.png',
#  '53mn8.png',
#  '55y2m.png',
#  '64m82.png',
#  '65ebm.png',
#  '62nb3.png',
#  '243mm.png',
#  '85dxn.png',
#  '75pfw.png',
#  '244e2.png',
#  '245y5.png',
#  '268g2.png',
#  '474ff.png',
#  '428b6.png',
#  '832f3.png',
#  '865wm.png',
#  '658xe.png',
#  '4433m.png',
#  '52447.png',
#  '7634y.png',
#  'b5fm7.png',
#  '76353.png',
#  'b28g8.png',
#  'b55d6.png',
#  'bmxpe.png',
#  'b685n.png',
#  'bdg84.png',
#  'bw44w.png',
#  'bnc2f.png',
#  'bn5mw.png',
#  'c2yn8.png',
#  'c4bny.png',
#  'byc82.png',
#  'c4mcm.png',
#  'c7gb3.png',
#  'c7nn8.png',
#  'c8n8c.png',
#  'c4527.png',
#  'c55c6.png',
#  'cd4eg.png',
#  'cdfen.png',
#  'cb8cf.png',
#  'cnex4.png',
#  'cfp86.png',
#  'cfw6e.png',
#  'd7en3.png',
#  'cnwyc.png',
#  'd3c8y.png',
#  'd66cn.png',
#  'd22y5.png',
#  'd22bd.png',
#  'd666m.png',
#  'dbny3.png',
#  'dc436.png',
#  'dd5w5.png',
#  'deneb.png',
#  'dn5df.png',
#  'dmxp8.png',
#  'dn2ym.png',
#  'dw6mn.png',
#  'dn26n.png',
#  'dnne7.png',
#  'e6b7y.png',
#  'e4gd7.png',
#  'dyp7n.png',
#  'e6m6p.png',
#  'e8e5e.png',
#  'e8dxn.png',
#  'edwny.png',
#  'e667x.png',
#  'een23.png',
#  'ef4mn.png',
#  'ef4np.png',
#  'ep85x.png',
#  'f6ww8.png',
#  'f753f.png',
#  'ffpxf.png',
#  'fdpgd.png',
#  'fp382.png',
#  'fncnb.png',
#  'fwxdp.png',
#  'g3dy6.png',
#  'g55b4.png',
#  'gcfgp.png',
#  'gbxyy.png',
#  'gc277.png',
#  'gecmf.png',
#  'gd8fb.png',
#  'ggd7m.png',
#  'gfbx6.png',
#  'gegw4.png',
#  'gm7n8.png',
#  'gm2c2.png',
#  'gnbde.png',
#  'gnc3n.png',
#  'gp22x.png',
#  'gng6e.png',
#  'gy8xb.png',
#  'gy5bf.png',
#  'gxx2p.png',
#  'm8m4x.png',
#  'm3b5p.png',
#  'm3wfw.png',
#  'mb4en.png',
#  'm23bp.png',
#  'm2576.png',
#  'mc35n.png',
#  'mcc2x.png',
#  'mfb3x.png',
#  'mp7wp.png',
#  'mggce.png',
#  'mw5p2.png',
#  'mxnw4.png',
#  'mwdf6.png',
#  'n3bm6.png',
#  'n5cm7.png',
#  'n4cpy.png',
#  'nb267.png',
#  'nb45d.png',
#  'n336e.png',
#  'n6nn2.png',
#  'nbwpn.png',
#  'nbf8m.png',
#  'ncfgb.png',
#  'ncw4g.png',
#  'ndecc.png',
#  'ndg2b.png',
#  'neecd.png',
#  'nfcb5.png',
#  'nfg23.png',
#  'nn4wx.png',
#  'nm46n.png',
#  'nmy2x.png',
#  'nnp4e.png',
#  'nn6mg.png',
#  'nnfx3.png',
#  'p4nm4.png',
#  'npxb7.png',
#  'ny3nn.png',
#  'p4pde.png',
#  'p6mn8.png',
#  'p5g5m.png',
#  'p24gn.png',
#  'p8c24.png',
#  'pcpg6.png',
#  'pdcp4.png',
#  'pg2yx.png',
#  'pmd3w.png',
#  'pgwnp.png',
#  'pme86.png',
#  'pp546.png',
#  'pw5nc.png',
#  'pwebm.png',
#  'pxne8.png',
#  'pwn5e.png',
#  'pym7p.png',
#  'w2e87.png',
#  'w2n7e.png',
#  'w2yp7.png',
#  'w6yne.png',
#  'wce5n.png',
#  'w52fn.png',
#  'wgnwp.png',
#  'wxcn8.png',
#  'wnmyn.png',
#  'x4f7g.png',
#  'x3deb.png',
#  'x6b5m.png',
#  'x4pnp.png',
#  'x6pdb.png',
#  'x76mn.png',
#  'x37bf.png',
#  'x775w.png',
#  'x362g.png',
#  'x7422.png',
#  'xe6eb.png',
#  'x7746.png',
#  'xf5g7.png',
#  'xwx7d.png',
#  'xyncc.png',
#  'y3c58.png',
#  'y5g87.png',
#  'y5n6d.png',
#  'y4n6m.png',
#  'y866y.png',
#  'y53c2.png',
#  'yf424.png',
#  'yw667.png',
#  'yx2d4.png',
#  '2cegf.png',
#  '2cg58.png',
#  '2gyb6.png',
#  '2mpnn.png',
#  '2n73f.png',
#  '2nbcx.png',
#  '3bnfnd.png',
#  '2x7bm.png',
#  '3cpwb.png',
#  '3ebnn.png',
#  '3d7bd.png',
#  '3mxdn.png',
#  '3n2b4.png',
#  '3nnpw.png',
#  '3nw7w.png',
#  '3n3cf.png',
#  '3x5fm.png',
#  '3x325.png',
#  '3xng6.png',
#  '3xcgg.png',
#  '3ym7f.png',
#  '4gycb.png',
#  '4dgf7.png',
#  '4n3mn.png',
#  '4w6mw.png',
#  '4nnf3.png',
#  '4w76g.png',
#  '5bb66.png',
#  '5ep3n.png',
#  '5expp.png',
#  '5bg8f.png',
#  '5f3gf.png',
#  '5mcy7.png',
#  '5mgn4.png',
#  '5nggg.png',
#  '5nm6d.png',
#  '5x7x5.png',
#  '5pm6b.png',
#  '6bnnm.png',
#  '6b4w6.png',
#  '5yxgp.png',
#  '6e6pn.png',
#  '6c3n6.png',
#  '6e554.png',
#  '6end3.png',
#  '6fgdw.png',
#  '6mege.png',
#  '6fn84.png',
#  '6mygb.png',
#  '6n443.png',
#  '6ng6w.png',
#  '6wg4n.png',
#  '6wnyc.png',
#  '6xen4.png',
#  '7b4bm.png',
#  '7bb7b.png',
#  '7bwm2.png',
#  '7d44m.png',
#  '7dgc2.png',
#  '7gnge.png',
#  '7gce6.png',
#  '7fde7.png',
#  '7w67m.png',
#  '7wyp4.png',
#  '7p852.png',
#  '8cm46.png',
#  '7y2x4.png',
#  '8d2nd.png',
#  '8eggg.png',
#  '8gecm.png',
#  '8gmnx.png',
#  '8gf7n.png',
#  '8n56m.png',
#  '8n2pg.png',
#  '8n62n.png',
#  '8npe3.png',
#  '8npd5.png',
#  '25w53.png',
#  '8w754.png',
#  '32dnn.png',
#  '33f7m.png',
#  '34fxm.png',
#  '33n73.png',
#  '53wb8.png',
#  '44ype.png',
#  '55w5c.png',
#  '53wp3.png',
#  '57gnx.png',
#  '58pnp.png',
#  '67dey.png',
#  '64b3p.png',
#  '76y6f.png',
#  '68x48.png',
#  '84w7x.png',
#  '78eec.png',
#  '77n6g.png',
#  '264m5.png',
#  '253dc.png',
#  '325fb.png',
#  '368y5.png',
#  '373gb.png',
#  '387g2.png',
#  '467d5.png',
#  '478nx.png',
#  '573d8.png',
#  '488de.png',
#  '537nf.png',
#  '574d7.png',
#  '664dn.png',
#  '2356g.png',
#  '5325m.png',
#  '728n8.png',
#  'b3xpn.png',
#  '28348.png',
#  '85622.png',
#  'b26nd.png',
#  'b5nmm.png',
#  'b84xc.png',
#  'b35f6.png',
#  'b43nw.png',
#  'bc8nf.png',
#  'bdbb3.png',
#  'be3bp.png',
#  'bm3p8.png',
#  'bgd4m.png',
#  'bf52c.png',
#  'bw6n6.png',
#  'bny23.png',
#  'bw5ym.png',
#  'c5xne.png',
#  'c6we6.png',
#  'c8fxy.png',
#  'c43b4.png',
#  'c753e.png',
#  'c482b.png',
#  'c6745.png',
#  'c3572.png',
#  'cfn53.png',
#  'cen55.png',
#  'cdcb3.png',
#  'cpe63.png',
#  'cpc8c.png',
#  'cx3wg.png',
#  'd3ycn.png',
#  'cwmny.png',
#  'd7nn3.png',
#  'd4n82.png',
#  'd8xcn.png',
#  'd75b5.png',
#  'dbfen.png',
#  'ddcne.png',
#  'dd764.png',
#  'ddmyg.png',
#  'ddnpf.png',
#  'ddpyb.png',
#  'de45x.png',
#  'dnxdp.png',
#  'dfnx4.png',
#  'dy3cx.png',
#  'dw3nn.png',
#  'dpbyd.png',
#  'e7nx4.png',
#  'e2mg2.png',
#  'e46pd.png',
#  'e43ym.png',
#  'e7x45.png',
#  'e46yw.png',
#  'efgx5.png',
#  'ee8fg.png',
#  'emwpn.png',
#  'efx34.png',
#  'exycn.png',
#  'f4fn2.png',
#  'f2fge.png',
#  'f4wfn.png',
#  'f5cm2.png',
#  'f6ne5.png',
#  'f7cey.png',
#  'f5e5e.png',
#  'f35xp.png',
#  'f22bn.png',
#  'f75cx.png',
#  'f85y3.png',
#  'f83pn.png',
#  'f364x.png',
#  'fbp2c.png',
#  'fcmem.png',
#  'fcne6.png',
#  'fg7mg.png',
#  'fg8n4.png',
#  'fg38b.png',
#  'fnbfw.png',
#  'fp762.png',
#  'fp5wn.png',
#  'fyfbn.png',
#  'fywb8.png',
#  'g7wxw.png',
#  'g3ex3.png',
#  'g8gnd.png',
#  'g842c.png',
#  'g247w.png',
#  'g2577.png',
#  'gd4mf.png',
#  'gcx6f.png',
#  'gewfy.png',
#  'gf2g4.png',
#  'gfp54.png',
#  'gn2xy.png',
#  'gn2d3.png',
#  'gw468.png',
#  'gw53m.png',
#  'gwn53.png',
#  'gwnm6.png',
#  'gxxpf.png',
#  'm2nf4.png',
#  'm4fd8.png',
#  'm6n4x.png',
#  'm75bf.png',
#  'm67b3.png',
#  'm448b.png',
#  'm457d.png',
#  'mg5nn.png',
#  'mcyfx.png',
#  'mcg43.png',
#  'mgdwb.png',
#  'mmfm6.png',
#  'mmg38.png',
#  'mmg2m.png',
#  'mwxwp.png',
#  'mxyxw.png',
#  'my84e.png',
#  'mye68.png',
#  'myf82.png',
#  'n4xx5.png',
#  'n2by7.png',
#  'n3x4c.png',
#  'n5n8b.png',
#  'n7ff2.png',
#  'n7meb.png',
#  'n7g4f.png',
#  'n8ydd.png',
#  'n373n.png',
#  'n464c.png',
#  'nbfx5.png',
#  'nd5wg.png',
#  'ncww7.png',
#  'neggn.png',
#  'ndme7.png',
#  'nf2n8.png',
#  'ng2gw.png',
#  'nf7bn.png',
#  'ngn26.png',
#  'ng756.png',
#  'nnn5p.png',
#  'nnn57.png',
#  'nny5e.png',
#  'nxc83.png',
#  'nwfde.png',
#  'nxn4f.png',
#  'ny5dp.png',
#  'ny8np.png',
#  'p2x7x.png',
#  'n2gmg.png',
#  'p2ym2.png',
#  'p5nce.png',
#  'p57fn.png',
#  'pcm7f.png',
#  'pdyc8.png',
#  'pg4bf.png',
#  'pg2pm.png',
#  'pm47f.png',
#  'pgm2e.png',
#  'pm363.png',
#  'pp87n.png',
#  'pnnwy.png',
#  'ppx77.png',
#  'pwmbn.png',
#  'w4cnn.png',
#  'pyf65.png',
#  'w8bnx.png',
#  'w46ep.png',
#  'w48cw.png',
#  'wb3ed.png',
#  'wd2gb.png',
#  'wecfd.png',
#  'wfy5m.png',
#  'wf684.png',
#  'wxy4n.png',
#  'wyc25.png',
#  'x5nyn.png',
#  'x8e8n.png',
#  'x8xnp.png',
#  'x38fn.png',
#  'x458w.png',
#  'x277e.png',
#  'xbcbx.png',
#  'x7547.png',
#  'xcmbp.png',
#  'xc68n.png',
#  'xdn65.png',
#  'xe8xm.png',
#  'xnfx5.png',
#  'xmcym.png',
#  'xfg65.png',
#  'xp24p.png',
#  'xxney.png',
#  'xymfn.png',
#  'xxw44.png',
#  'y4ec2.png',
#  'y5dpp.png',
#  'y7d75.png',
#  'ycnfc.png',
#  'ybfx6.png',
#  'yd3m3.png',
#  'ydd3g.png',
#  'yd755.png',
#  'ydg8n.png',
#  'yg5bb.png',
#  'yw7ny.png',
#  'ypw3d.png',
#  'ygenn.png',
#  'yy824.png',
#  'yyg5g.png',
#  '57b27.png',
#  '6bxwg.png',
#  'xfgxb.png',
#  'fxpw3.png',
#  '6ecbn.png',
#  '77wp4.png',
#  '556wd.png',
#  '226md.png',
#  'p8wwf.png',
#  '5wddw.png',
#  '5g5e5.png',
#  'xfn6n.png',
#  'feyc8.png',
#  'cdmn8.png',
#  'eppg3.png',
#  'wm746.png',
#  '7xcyd.png',
#  'nmw46.png',
#  'mdyp7.png',
#  'mc8w2.png',
#  '6ge3p.png',
#  'd378n.png',
#  '46mbm.png',
#  '65m85.png',
#  'm8gmx.png',
#  '3b4we.png',
#  '7mgmf.png',
#  'n5wbg.png',
#  'p2m6n.png',
#  'n3ffn.png',
#  '823p2.png',
#  '36bc2.png',
#  'd4ppy.png',
#  'gc2wd.png',
#  'm5meg.png',
#  'cg5dd.png',
#  '6dd2y.png',
#  'nfbg8.png',
#  '5n728.png',
#  'befbd.png',
#  'pmf5w.png',
#  'by5y3.png',
#  'gnf85.png',
#  'excmn.png',
#  'mpxfb.png',
#  '6n6gg.png',
#  '2en7g.png',
#  '2w4y7.png',
#  'gymmn.png',
#  '7cgym.png',
#  'fpw76.png',
#  'fc2ff.png',
#  '573bn.png',
#  'eng53.png',
#  '6pwcn.png',
#  'ppwyd.png',
#  'en32e.png',
#  '6g45w.png',
#  '6c3p5.png',
#  '72m6f.png',
#  'cffp4.png',
#  'mnef5.png',
#  'mmc5n.png',
#  '2bg48.png',
#  'y48c3.png',
#  '88bgx.png',
#  '33ng4.png',
#  'yew6p.png',
#  'xnd3y.png',
#  'yd38e.png',
#  'wbncw.png',
#  'mm3nn.png',
#  '7xd5m.png',
#  'e2d66.png',
#  'mdxpn.png',
#  'ebcbx.png',
#  '5bgp2.png',
#  '5mf7c.png',
#  '6pfy4.png',
#  '5n732.png',
#  'efg72.png',
#  'be6np.png',
#  'yyn57.png',
#  'cewnm.png',
#  '77387.png',
#  'n5x2n.png',
#  'nm248.png',
#  'gny6b.png',
#  'y33nm.png',
#  'wnpec.png',
#  '4exnn.png',
#  'yf28d.png',
#  'y4g3b.png',
#  '3ebpw.png',
#  '3p4nn.png',
#  'x74b2.png',
#  'bny4w.png',
#  'n3m6x.png',
#  'men4f.png',
#  '7gp47.png',
#  'ffnxn.png',
#  '4n2yg.png',
#  'm22e3.png',
#  '56ncx.png',
#  'e3ndn.png',
#  'gpnxn.png',
#  'de7f8.png',
#  'fw3b2.png',
#  'px2xp.png',
#  '36w25.png',
#  '5x5nx.png',
#  'ng46m.png',
#  'w8f36.png',
#  'wwmn6.png',
#  '6825y.png',
#  '4gb3f.png',
#  'enpw2.png',
#  'bp2d4.png',
#  'cc845.png',
#  'cfc56.png',
#  'wc2bd.png',
#  '8cccc.png',
#  'f858x.png',
#  '678w3.png',
#  'x5f54.png',
#  '3n7mx.png',
#  'ffd6p.png',
#  'mmy5n.png',
#  '3pe4g.png',
#  'xngxc.png',
#  '43p5d.png',
#  'ny3dw.png',
#  'bcwnn.png',
#  '7gmf3.png',
#  '4ynf3.png',
#  'gfxcc.png',
#  '5np4m.png',
#  'nybcx.png',
#  '2p2y8.png',
#  'c4bgd.png',
#  '3fbxd.png',
#  'mpmy5.png',
#  '5nxnn.png',
#  'p2dw7.png',
#  '4yc85.png',
#  '8n5pn.png',
#  '4m2w5.png',
#  'nbwnn.png',
#  'bwmee.png',
#  '37ep6.png',
#  '23n88.png',
#  'xce8d.png',
#  '2npg6.png',
#  'ne325.png',
#  'fcey3.png',
#  'wye85.png',
#  'f2m8n.png',
#  'pxdwp.png',
#  'g6n7x.png',
#  'b6f2p.png',
#  'y2ye8.png',
#  'y2436.png',
#  '6m5eg.png',
#  '2nf26.png',
#  '662bw.png',
#  'mbp2y.png',
#  'nc4yg.png',
#  'xgcxy.png',
#  '43gey.png',
#  'edg3p.png',
#  'gp7c5.png',
#  'fy2nd.png',
#  'd3c7y.png',
#  'dbex3.png',
#  '56m6y.png',
#  'ecd4w.png',
#  'm74dm.png',
#  '25257.png',
#  '66wp5.png',
#  'x2cnn.png',
#  'mn5c4.png',
#  'ypp8f.png',
#  '33b22.png',
#  'x44n4.png',
#  'bpwd7.png',
#  'xf4p4.png',
#  'd22n7.png',
#  'dmw8n.png',
#  'fc6xb.png',
#  'nxx25.png',
#  'ncyx8.png',
#  '44c22.png',
#  '4ycex.png',
#  '445cc.png',
#  '5n3w4.png',
#  '57wdp.png',
#  'ygfwe.png',
#  'mgw3n.png',
#  'enn7n.png',
#  'pyefb.png',
#  '7cdge.png',
#  'pn7pn.png',
#  'w4x2m.png',
#  '5ywwf.png',
#  'gc83b.png',
#  'n8pfe.png',
#  'g888x.png',
#  'yfdn7.png',
#  '33p4e.png',
#  '4cfw8.png',
#  '8n5p3.png',
#  'b4y5x.png',
#  'e76n4.png',
#  'pe4xn.png',
#  'xemyg.png',
#  'ewnx8.png',
#  'e84n2.png',
#  'b2nen.png',
#  'px8n8.png',
#  'gm6nn.png',
#  'p7fyp.png',
#  'g7gnf.png',
#  'bbymy.png',
#  'yxd7m.png',
#  'y7x8p.png',
#  'cfc2y.png',
#  'nw5b2.png',
#  'y32yy.png',
#  '47e4p.png',
#  'd236n.png',
#  'pgmn2.png',
#  'pybee.png',
#  'ccn2x.png',
#  '43mn5.png',
#  'ewcf5.png',
#  'cgcgb.png',
#  'defyx.png',
#  '8bbw8.png',
#  '5bnd7.png',
#  'bgb48.png',
#  'nbcgb.png',
#  'myc3c.png',
#  'mx8bb.png',
#  '3bnyf.png',
#  'nxcmn.png',
#  '7f8b3.png',
#  'yf347.png',
#  'c2fb7.png',
#  '3w2bw.png',
#  '2mg87.png',
#  'dxwcw.png',
#  '8nn73.png',
#  'ccf2w.png',
#  'pf5ng.png',
#  '87nym.png',
#  'efe62.png',
#  'pdw38.png',
#  'ymp7g.png',
#  'gy433.png',
#  '4nc37.png',
#  '8bbm4.png',
#  '3bx86.png',
#  'x3fwf.png',
#  '2b827.png',
#  '2cgyx.png',
#  '2g7nm.png',
#  '2g783.png',
#  '2nx38.png',
#  '2pfpn.png',
#  '2ycn8.png',
#  '2yggg.png',
#  '3bd8f.png',
#  '3den6.png',
#  '3dgmf.png',
#  '3g2w6.png',
#  '3ny45.png',
#  '4c8n8.png',
#  '4d22m.png',
#  '4f8yp.png',
#  '4fp5g.png',
#  '5dxnm.png',
#  '5gcd3.png',
#  '5mnpd.png',
#  '5n245.png',
#  '5nnff.png',
#  '5npdn.png',
#  '5p3mm.png',
#  '5xwcg.png',
#  '6b46g.png',
#  '6bdn5.png',
#  '6f857.png',
#  '6gnm3.png',
#  '6mn8n.png',
#  '6ng6n.png',
#  '6wb76.png',
#  '7dwx4.png',
#  '7dxbd.png',
#  '7dyww.png',
#  '7e2y7.png',
#  '7g3nf.png',
#  '7nnnx.png',
#  '7pcd7.png',
#  '7pn5g.png',
#  '7wnpm.png',
#  '8b735.png',
#  '8c2wy.png',
#  '8c23f.png',
#  '8e32m.png',
#  '8fexn.png',
#  '8g4yp.png',
#  '8ne4g.png',
#  '8pfxx.png',
#  '8w875.png',
#  '8y6b3.png',
#  '22d5n.png',
#  '24f6w.png',
#  '24pew.png',
#  '25p2m.png',
#  '28x47.png',
#  '34pcn.png',
#  '38n57.png',
#  '42nxy.png',
#  '43xfe.png',
#  '44fyb.png',
#  '44xe8.png',
#  '58b5m.png',
#  '63pxe.png',
#  '68wfd.png',
#  '73mnx.png',
#  '74eyg.png',
#  '76n7p.png',
#  '76nxn.png',
#  '82fx2.png',
#  '87d4c.png',
#  '88y52.png',
#  '377xx.png',
#  '378e5.png',
#  '646x8.png',
#  '664nf.png',
#  '675p3.png',
#  '677g3.png',
#  '785n4.png',
#  '4743p.png',
#  '8684m.png',
#  '63824.png',
#  '74853.png',
#  'b4d7c.png',
#  'b2g8e.png',
#  'b4ncn.png',
#  'b5dn4.png',
#  'b5pnn.png',
#  'bd3b7.png',
#  'bgem5.png',
#  'bnc5f.png',
#  'bp6mw.png',
#  'bw5nf.png',
#  'bxxfc.png',
#  'byfgn.png',
#  'c2g4d.png',
#  'c2pg6.png',
#  'c3n8x.png',
#  'c6f8g.png',
#  'c353e.png',
#  'c86md.png',
#  'cdf77.png',
#  'cd6p4.png',
#  'cm6yb.png',
#  'cnmnn.png',
#  'cwgyx.png',
#  'cwdnx.png',
#  'cy3nw.png',
#  'd2nbn.png',
#  'd2ycw.png',
#  'd7c5x.png',
#  'd6fcn.png',
#  'dbpcd.png',
#  'd8dce.png',
#  'dce8y.png',
#  'dcnp8.png',
#  'ddcdd.png',
#  'deep5.png',
#  'dmx8p.png',
#  'dw8d3.png',
#  'dnmd8.png',
#  'dyxnc.png',
#  'e25xg.png',
#  'e5n66.png',
#  'ec6pm.png',
#  'e72cd.png',
#  'efb3f.png',
#  'egxmp.png',
#  'en4n4.png',
#  'ennmm.png',
#  'f8f8g.png',
#  'f74x3.png',
#  'fp3wy.png',
#  'f228n.png',
#  'g7fmc.png',
#  'g2fnw.png',
#  'g78gn.png',
#  'gdng3.png',
#  'gnbn4.png',
#  'gpxng.png',
#  'm4g8g.png',
#  'm5ym2.png',
#  'm3588.png',
#  'mbf58.png',
#  'md344.png',
#  'mfc35.png',
#  'mddgb.png',
#  'n4b4m.png',
#  'n4wwn.png',
#  'n5w5g.png',
#  'n6f4b.png',
#  'n7dyb.png',
#  'n6xc5.png',
#  'n7enn.png',
#  'n7ebx.png',
#  'n265y.png',
#  'n8fp6.png',
#  'nbmx7.png',
#  'nbp3e.png',
#  'nf8b8.png',
#  'ndyfe.png',
#  'nfd8g.png',
#  'nfcwy.png',
#  'ng6yp.png',
#  'nfndw.png',
#  'nwg2m.png',
#  'nnf8b.png',
#  'nngxc.png',
#  'nwncn.png',
#  'nxxf8.png',
#  'pbpgc.png',
#  'p8ngx.png',
#  'pcede.png',
#  'pf4nb.png',
#  'pgg3n.png',
#  'pnmxf.png',
#  'pmg55.png',
#  'w4cdc.png',
#  'w4nfx.png',
#  'w6pxy.png',
#  'w7e6m.png',
#  'w75w8.png',
#  'wdww8.png',
#  'wddcp.png',
#  'wg625.png',
#  'wm47f.png',
#  'x4gg5.png',
#  'wmpmp.png',
#  'x347n.png',
#  'xcf88.png',
#  'xbem6.png',
#  'xdcn4.png',
#  'xnn4d.png',
#  'xnnc3.png',
#  'xxbm5.png',
#  'xw465.png',
#  'xyyyw.png',
#  'y5w28.png',
#  'y2xg4.png',
#  'ycmcw.png',
#  'y7mnm.png',
#  'yemy4.png',
#  'yeyn4.png',
#  'ywn6f.png',
#  ...]

# %%
#total no of images in dataset
n=len(os.listdir("/content/drive/MyDrive/Colab Notebooks/samples"))
n
# Out:
# 1070

# %%
#defining size of image
imgshape=(50,200,1) #50-height, 200-width, 1-no of channels

# %%
character= string.ascii_lowercase + "0123456789" # All symbols captcha can contain
nchar = len(character) #total number of char possible
nchar
# Out:
# 36

# %%
#preprocesss image
def preprocess():
  X = np.zeros((n,50,200,1)) #1070*50*200 array with all entries 0
  y = np.zeros((5,n,nchar)) #5*1070*36(5 letters in captcha) with all entries 0

  for i, pic in enumerate(os.listdir("/content/drive/MyDrive/Colab Notebooks/samples")):
  #i represents index no. of image in directory 
  #pic contains the file name of the particular image to be preprocessed at a time
    
    img = cv2.imread(os.path.join("/content/drive/MyDrive/Colab Notebooks/samples", pic), cv2.IMREAD_GRAYSCALE) #Read image in grayscale format
    pic_target = pic[:-4]#this drops the .png extension from file name and contains only the captcha for training
    
    if len(pic_target) < 6: #captcha is not more than 5 letters
      img = img / 255.0 #scales the image between 0 and 1
      img = np.reshape(img, (50, 200, 1)) #reshapes image to width 200 , height 50 ,channel 1 

      target=np.zeros((5,nchar)) #creates an array of size 5*36 with all entries 0

      for j, k in enumerate(pic_target):
      #j iterates from 0 to 4(5 letters in captcha)
      #k denotes the letter in captcha which is to be scanned
         index = character.find(k) #index stores the position of letter k of captcha in the character string
         target[j, index] = 1 #replaces 0 with 1 in the target array at the position of the letter in captcha

      X[i] = img #stores all the images
      y[:,i] = target #stores all the info about the letters in captcha of all images

  return X,y

# %%
#create model
def createmodel():
    img = layers.Input(shape=imgshape) # Get image as an input of size 50,200,1
    conv1 = layers.Conv2D(16, (3, 3), padding='same', activation='relu')(img) #50*200
    mp1 = layers.MaxPooling2D(padding='same')(conv1)  # 25*100
    conv2 = layers.Conv2D(32, (3, 3), padding='same', activation='relu')(mp1)
    mp2 = layers.MaxPooling2D(padding='same')(conv2)  # 13*50
    conv3 = layers.Conv2D(32, (3, 3), padding='same', activation='relu')(mp2)
    bn = layers.BatchNormalization()(conv3) #to improve the stability of model
    mp3 = layers.MaxPooling2D(padding='same')(bn)  # 7*25
    
    flat = layers.Flatten()(mp3) #convert the layer into 1-D

    outs = []
    for _ in range(5): #for 5 letters of captcha
        dens1 = layers.Dense(64, activation='relu')(flat)
        drop = layers.Dropout(0.5)(dens1) #drops 0.5 fraction of nodes
        res = layers.Dense(nchar, activation='sigmoid')(drop)

        outs.append(res) #result of layers
    
    # Compile model and return it
    model = Model(img, outs) #create model
    model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=["accuracy"])
    return model

# %%
#Create model
model=createmodel();
model.summary();
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 50, 200, 1)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 50, 200, 16)  160         ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 25, 100, 16)  0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 25, 100, 32)  4640        ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 13, 50, 32)  0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 13, 50, 32)   9248        ['max_pooling2d_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 13, 50, 32)  128         ['conv2d_2[0][0]']
#  alization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 7, 25, 32)   0           ['batch_normalization[0][0]']
#
#  flatten (Flatten)              (None, 5600)         0           ['max_pooling2d_2[0][0]']
#
#  dense (Dense)                  (None, 64)           358464      ['flatten[0][0]']
#
#  dense_2 (Dense)                (None, 64)           358464      ['flatten[0][0]']
#
#  dense_4 (Dense)                (None, 64)           358464      ['flatten[0][0]']
#
#  dense_6 (Dense)                (None, 64)           358464      ['flatten[0][0]']
#
#  dense_8 (Dense)                (None, 64)           358464      ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 64)           0           ['dense[0][0]']
#
#  dropout_1 (Dropout)            (None, 64)           0           ['dense_2[0][0]']
#
#  dropout_2 (Dropout)            (None, 64)           0           ['dense_4[0][0]']
#
#  dropout_3 (Dropout)            (None, 64)           0           ['dense_6[0][0]']
#
#  dropout_4 (Dropout)            (None, 64)           0           ['dense_8[0][0]']
#
#  dense_1 (Dense)                (None, 36)           2340        ['dropout[0][0]']
#
#  dense_3 (Dense)                (None, 36)           2340        ['dropout_1[0][0]']
#
#  dense_5 (Dense)                (None, 36)           2340        ['dropout_2[0][0]']
#
#  dense_7 (Dense)                (None, 36)           2340        ['dropout_3[0][0]']
#
#  dense_9 (Dense)                (None, 36)           2340        ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 1,818,196
# Trainable params: 1,818,132
# Non-trainable params: 64
# __________________________________________________________________________________________________

# %%
X,y=preprocess()

# %%
#split the 1070 samples where 970 samples will be used for training purpose
X_train, y_train = X[:970], y[:, :970]
X_test, y_test = X[970:], y[:, 970:]

# %%
#Applying the model
hist = model.fit(X_train, [y_train[0], y_train[1], y_train[2], y_train[3], y_train[4]], batch_size=64, epochs=60, validation_split=0.1)
#batch size- 32 defines no. of samples per gradient update
#Validation split=0.2 splits the training set in 80-20% for training nd testing
# Out:
# Epoch 1/60
- val_dense_3_accuracy: 0.9485 - val_dense_5_accuracy: 0.8866 - val_dense_7_accuracy: 0.8660 - val_dense_9_accuracy: 0.8969
# Epoch 60/60
# 14/14 [==============================] - 7s 505ms/step - loss: 1.6394 - dense_1_loss: 0.1604 - dense_3_loss: 0.2106 - dense_5_loss: 0.4179 - dense_7_loss: 0.4425 - dense_9_loss: 0.4080 - dense_1_accuracy: 0.9370 - dense_3_accuracy: 0.9210 - dense_5_accuracy: 0.8316 - dense_7_accuracy: 0.8190 - dense_9_accuracy: 0.8282 - val_loss: 1.6057 - val_dense_1_loss: 0.0435 - val_dense_3_loss: 0.2352 - val_dense_5_loss: 0.4077 - val_dense_7_loss: 0.6829 - val_dense_9_loss: 0.2364 - val_dense_1_accuracy: 0.9691 - val_dense_3_accuracy: 0.9485 - val_dense_5_accuracy: 0.8969 - val_dense_7_accuracy: 0.8557 - val_dense_9_accuracy: 0.9072

# %%
#graph of loss vs epochs
for label in ["loss"]:
  plt.plot(hist.history[label],label=label)
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %%
#graph of accuracy of dense_2 vs epochs
for label in ["val_dense_1_accuracy"]:
  plt.plot(hist.history[label],label=label)
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Accuracy of Dense 2 layer")
plt.show()

# %%
#graph of accuracy of dense_3 vs epochs
for label in ["val_dense_3_accuracy"]:
  plt.plot(hist.history[label],label=label)
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Accuracy of Dense 4 layer")
plt.show()

# %%
#graph of accuracy of dense_5 vs epochs
for label in ["val_dense_5_accuracy"]:
  plt.plot(hist.history[label],label=label)
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Accuracy of Dense 4 layer")
plt.show()

# %%
#graph of accuracy of dense_7 vs epochs
for label in ["val_dense_7_accuracy"]:
  plt.plot(hist.history[label],label=label)
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Accuracy of Dense 4 layer")
plt.show()

# %%
#graph of accuracy of dense_9 vs epochs
for label in ["val_dense_9_accuracy"]:
  plt.plot(hist.history[label],label=label)
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Accuracy of Dense 4 layer")
plt.show()

# %%
#Loss on training set
#Finding Loss on training set
preds = model.evaluate(X_train, [y_train[0], y_train[1], y_train[2], y_train[3], y_train[4]])
print ("Loss on training set= " + str(preds[0]))
# Out:
# 31/31 [==============================] - 2s 73ms/step - loss: 0.2066 - dense_1_loss: 0.0045 - dense_3_loss: 0.0268 - dense_5_loss: 0.0517 - dense_7_loss: 0.0850 - dense_9_loss: 0.0385 - dense_1_accuracy: 0.9959 - dense_3_accuracy: 0.9938 - dense_5_accuracy: 0.9887 - dense_7_accuracy: 0.9825 - dense_9_accuracy: 0.9866
# Loss on training set= 0.20655590295791626

# %%
#Finding loss on test set
preds = model.evaluate(X_test, [y_test[0], y_test[1], y_test[2], y_test[3], y_test[4]])
print ("Loss on testing set= " + str(preds[0]))
# Out:
# 4/4 [==============================] - 0s 53ms/step - loss: 2.4393 - dense_1_loss: 0.0073 - dense_3_loss: 0.3861 - dense_5_loss: 0.6947 - dense_7_loss: 0.9232 - dense_9_loss: 0.4279 - dense_1_accuracy: 1.0000 - dense_3_accuracy: 0.9200 - dense_5_accuracy: 0.8300 - dense_7_accuracy: 0.7500 - dense_9_accuracy: 0.8700
# Loss on testing set= 2.4393444061279297

# %%
#to predict captcha
def predict(filepath):
    img = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)

    if img is not None: #image foud at file path
        img = img / 255.0 #Scale image
    else:
        print("Not detected");

    res = np.array(model.predict(img[np.newaxis, :, :, np.newaxis])) #np.newaxis=1 
    #added this bcoz x_train 970*50*200*1
    #returns array of size 1*5*36 
    result = np.reshape(res, (5, 36)) #reshape the array
    k_ind = []
    probs = []
    for i in result:
        k_ind.append(np.argmax(i)) #adds the index of the char found in captcha

    capt = '' #string to store predicted captcha
    for k in k_ind:
        capt += character[k] #finds the char corresponding to the index
    return capt

# %%
#Check model on samples
img=cv2.imread('/content/drive/MyDrive/Colab Notebooks/samples/3ygde.png',cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap=plt.get_cmap('gray'))

# %%
print("Predicted Captcha =",predict('/content/drive/MyDrive/Colab Notebooks/samples/3ygde.png'))
# Out:
# Predicted Captcha = 3ygde

# %%
#Sample 2
img=cv2.imread('/content/drive/MyDrive/Colab Notebooks/samples/243mm.png',cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap=plt.get_cmap('gray'))

# %%
print("Predicted Captcha =",predict('/content/drive/MyDrive/Colab Notebooks/samples/243mm.png'))
# Out:
# Predicted Captcha = 243mm

# %%
#Sample 3
img=cv2.imread('/content/drive/MyDrive/Colab Notebooks/samples/268g2.png',cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap=plt.get_cmap('gray'))

# %%
print("Predicted Captcha =",predict('/content/drive/MyDrive/Colab Notebooks/samples/268g2.png'))
# Out:
# Predicted Captcha = 268g2

# %%
#Sample 4
img=cv2.imread('/content/drive/MyDrive/Colab Notebooks/samples/25257.png',cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap=plt.get_cmap('gray'))

# %%
print("Predicted Captcha =",predict('/content/drive/MyDrive/Colab Notebooks/samples/25257.png'))
# Out:
# Predicted Captcha = 25257

# %%
#Sample 5
img=cv2.imread('/content/drive/MyDrive/Colab Notebooks/samples/36bc2.png',cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap=plt.get_cmap('gray'))

# %%
print("Predicted Captcha =",predict('/content/drive/MyDrive/Colab Notebooks/samples/36bc2.png'))
# Out:
# Predicted Captcha = 36bc2

# %%
#Sample 6
img=cv2.imread('/content/drive/MyDrive/Colab Notebooks/samples/2n73f.png',cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap=plt.get_cmap('gray'))

# %%
print("Predicted Captcha =",predict('/content/drive/MyDrive/Colab Notebooks/samples/2n73f.png'))
# Out:
# Predicted Captcha = 2n73f

# %%
#Sample 7
img=cv2.imread('/content/drive/MyDrive/Colab Notebooks/samples/24pew.png',cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap=plt.get_cmap('gray'))

# %%
print("Predicted Captcha =",predict('/content/drive/MyDrive/Colab Notebooks/samples/24pew.png'))
# Out:
# Predicted Captcha = 24pew

# %%
#Sample 8
img=cv2.imread('/content/drive/MyDrive/Colab Notebooks/samples/2b827.png',cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap=plt.get_cmap('gray'))

# %%
print("Predicted Captcha =",predict('/content/drive/MyDrive/Colab Notebooks/samples/2b827.png'))
# Out:
# Predicted Captcha = 2b827

# %%
#Sample 9
img=cv2.imread('/content/drive/MyDrive/Colab Notebooks/samples/2cegf.png',cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap=plt.get_cmap('gray'))

# %%
print("Predicted Captcha =",predict('/content/drive/MyDrive/Colab Notebooks/samples/2cegf.png'))
# Out:
# Predicted Captcha = 2cegf

# %%
#Sample 10
img=cv2.imread('/content/drive/MyDrive/Colab Notebooks/samples/2npg6.png',cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap=plt.get_cmap('gray'))

# %%
print("Predicted Captcha =",predict('/content/drive/MyDrive/Colab Notebooks/samples/2npg6.png'))
# Out:
# Predicted Captcha = 2npg6
